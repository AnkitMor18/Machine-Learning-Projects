# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import random

# %%
columns = ['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longtitude','Y house price of unit area'
]

# %%
columns
# Out:
# ['X1 transaction date',
#  'X2 house age',
#  'X3 distance to the nearest MRT station',
#  'X4 number of convenience stores',
#  'X5 latitude',
#  'X6 longtitude',
#  'Y house price of unit area']

# %%
df = pd.read_excel('C:/Users/Sumit/Downloads/Real estate valuation data set.xlsx')

# %%
df_X = df.iloc[:,[1,2,3,4,5]]

# %%
df_Y = df.iloc[:,[-1]]

# %%
print('Y Shape : ',df_Y.shape ,', Shape : X', df_X.shape)
# Out:
# Y Shape :  (414, 1) , Shape : X (414, 5)

# %%
x = np.array(df_X)
y = np.array(df_Y)

# %%
# Standardization
x1 = preprocessing.scale(x)

# %%
x_a = (x - np.mean(x)) / np.std(x)

# %%
# add a column of all ones at the end of the array to exclude the matter of intercept 
x2 = np.c_[x1 , np.ones(x1.shape[0])]

# %%
# choosing all the parameter initially equal to one

# %% [markdown]
# ## Algorithm implementation

# %%
alg1 = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y,random_state=1)

# %%
x_train.shape , y_train.shape
# Out:
# ((310, 6), (310, 1))

# %%
alg1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = alg1.predict(x_train)

# %%
y_test_pred = alg1.predict(x_test)

# %%
def score(y_truth , y_pred):
    u = ((y_truth - y_pred)**2).sum()
    v = ((y_truth - y_truth.mean())**2).sum()
    return 1-u/v

# %%
score(y_train,y_train_pred)
# Out:
# 0.5319658374292333

# %%
alg1.coef_
# Out:
# array([[-2.72130377, -5.97235163,  3.21655588,  2.77653664, -0.64528891,
#          0.        ]])

# %%
score(y_test,y_test_pred)
# Out:
# 0.681769971480737

# %% [markdown]
# ## Own Model Implementation

# %%
theta = np.ones(x2.shape[1])
theta.shape , x2.shape , y.shape
# Out:
# ((6,), (414, 6), (414, 1))

# %%
theta = theta.reshape(6,1)

# %%
cost_value = []

for i in range(iteration):
    m=len(y)
    y_pred = np.dot(x2 ,theta)
    errors = y_pred - y
    deriv = (1/len(y)) * np.dot(x2.T, errors) 
    a = (lr*deriv)
    theta  = theta - a
    cost = cost_funct(x2,y,theta)
    cost_value.append(cost)

print('cofficients' , theta)
print('intercept' , theta[-1])
print(cost_value)
# Out:
# cofficients [[-3.05992858]
#  [-5.36894108]
#  [ 3.42160882]
#  [ 2.94717174]
#  [-0.11964695]
#  [37.98019324]]
# intercept [37.98019324]
# ...

# %%
def score(y_truth , y_pred):
    u = ((y_truth - y_pred)**2).sum()
    v = ((y_truth - y_truth.mean())**2).sum()
    return 1-u/v

# %%
print('score : ' , score(y , y_pred))
print('cofficients' , theta)
# Out:
# score :  0.5711617064827441
# cofficients [[-3.05992858]
#  [-5.36894108]
#  [ 3.42160882]
#  [ 2.94717174]
#  [-0.11964695]
#  [37.98019324]]

# %%
y_pred
# Out:
# array([[48.5246244 ],
#        [49.15674926],
#        [46.74278224],
#        [46.74278224],
#        [47.79272776],
#        [33.65488125],
#        [41.2313165 ],
#        [45.53084411],
#        [ 7.84212964],
#        [33.41428306],
#        [33.7346204 ],
#        [52.17000276],
#        [41.86700401],
#        [29.53435032],
#        [44.09077594],
#        [35.93572764],
#        [50.24037798],
#        [39.04802422],
#        [45.3388434 ],
#        [49.86502763],
#        [33.95398733],
#        [48.11859881],
#        [29.85788923],
#        [48.22616554],
#        [35.5808554 ],
#        [32.3529296 ],
#        [48.67273068],
#        [41.27927269],
#        [40.9035398 ],
#        [46.04528471],
#        [11.73760793],
#        [42.77317343],
#        [32.53977723],
#        [45.91712832],
#        [49.25701687],
#        [32.43688178],
#        [31.64703194],
#        [30.58396468],
#        [46.8813678 ],
#        [45.83648585],
#        [15.25198859],
# ...
